# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# G:\anaconda\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import os

print(os.listdir(r"C:\Users\hp\Desktop\New folder\Python Object and Data Structure Basics\csv file\All Files\All Files"))
# Out:
# ['2010-capitalbikeshare-tripdata.xlsx', 'Advartising.csv', 'anime.csv', 'anscombe.csv', 'attention.csv', 'Automobiledata.csv', 'Boston.csv', 'brain_networks.csv', 'breastCancer.csv', 'breastcancerdata.csv', 'California House Price.csv', 'CarPrice Prediction.csv', 'car_crashes.csv', 'Churn.csv', 'Classifieddata.csv', 'Country.csv', 'CountryNotes.csv', 'Cricket testdataset1.csv', 'cricket traindataset.csv', 'datasets_105471_251283_data.csv', 'datasets_11167_15520_test.csv', 'datasets_11167_15520_train.csv', 'datasets_1489_2704_auto-mpg.csv', 'datasets_201575_443946_Cricket_chirps.csv', 'datasets_2179_10093_Interview.csv', 'datasets_228_482_diabetes.csv', 'datasets_31481_40149_petrol_consumption.csv', 'datasets_33080_43333_car data.csv', 'datasets_33180_43520_heart.csv', 'datasets_383055_741735_CarPrice_Assignment.csv', 'datasets_383055_741735_Data Dictionary.xlsx', 'datasets_4458_8204_winequality-red.csv', 'datasets_4471_6849_bank.csv', 'datasets_535863_984605_Foreign_Exchange_Rates.csv', 'datasets_577170_1055509_russian_air_service_CARGO_AND_PARCELS.csv', 'datasets_579_1104_comptagesvelo2015.csv', 'datasets_596958_1073629_Placement_Data_Full_Class.csv', 'datasets_673_1282_beers.csv', 'datasets_673_1282_breweries.csv', 'datasets_74977_169835_StudentsPerformance.csv', 'datasets_7721_10938_Mall_Customers.csv', 'datasets_79726_185469_Seed_Data.csv', 'datasets_88705_204267_Real estate.csv', 'diamonds.csv', 'DoctorsCosultationfees.csv', 'dots.csv', 'Ecommerce Customers', 'emailspamdetetion.csv', 'Ensurance.csv', 'exercise.csv', 'Exploration', 'flights.csv', 'fmri.csv', 'forestfires.csv', 'framingham_heart_disease.csv', 'gammas.csv', 'glassdoorjob.csv', 'heart.csv', 'hmda_lar.csv', 'HR_comma_sep.csv', 'Hyberman.csv', 'insurance', 'insurance1.csv', 'iris.csv', 'KC house data.csv', 'Loan payments data.csv', 'loan_data.csv', 'Mall_customers.csv', 'Marketsales.csv', 'mpg.csv', 'netflix.csv', 'netflix_titles.csv', 'NobelPrize.csv', 'NYCTaxiFares.csv', 'Personal Loan Data.csv', 'planets.csv', 'PotatoPrice.csv', 'Python', 'Python Object and Data Structure Basics - Shortcut.lnk', 'rating.csv', 'README.md', 'Salary.csv', 'Sample - Superstore.xls', 'Sample_submission.xlsx', 'Series.csv', 'SeriesNotes.csv', 'slr03.xls', 'Startups.csv', 'Stock Price.csv', 'Stockdata.csv', 'Studentdata.csv', 'test.csv', 'test.csv.zip', 'TestA.csv', 'tips.csv', 'titanic.csv', 'train.csv.zip', 'train3.csv', 'TrainA.csv', 'Unemployment Youth_API_ILO_country_YU.csv', 'USA Houseing.xlsx', 'Waether AUS.csv', 'Wine.csv', 'winequality.csv']

# %%
df = pd.read_excel(r"C:\Users\hp\Desktop\New folder\Python Object and Data Structure Basics\csv file\All Files\All Files\Sample - Superstore.xls")
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
df.tail(5)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# 9989       33180   South  FUR-FU-10001889        Furniture  Furnishings
# 9990       92627    West  FUR-FU-10000747        Furniture  Furnishings
# 9991       92627    West  TEC-PH-10003645       Technology       Phones
# 9992       92627    West  OFF-PA-10004041  Office Supplies        Paper
# 9993       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name    Sales  Quantity  \
# 9989                             Ultra Door Pull Handle   25.248         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.960         2
# 9991                              Aastra 57i VoIP phone  258.576         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.600         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# 9991       0.2  19.3932
# 9992       0.0  13.3200
# 9993       0.0  72.9480
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(3), object(13)
# memory usage: 1.6+ MB

# %%
df.drop('Row ID', axis= 1, inplace = True)

# %%
df.shape
# Out:
# (9994, 20)

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df_subset = df.loc[[i for i in range(5,10)], ['Customer ID', 'Customer Name', 'City', 'Postal Code', 'Sales']]
df_subset
# Out:
#   Customer ID    Customer Name         City  Postal Code    Sales
# 5    BH-11710  Brosina Hoffman  Los Angeles        90032   48.860
# 6    BH-11710  Brosina Hoffman  Los Angeles        90032    7.280
# 7    BH-11710  Brosina Hoffman  Los Angeles        90032  907.152
# 8    BH-11710  Brosina Hoffman  Los Angeles        90032   18.504
# 9    BH-11710  Brosina Hoffman  Los Angeles        90032  114.900

# %%
df_subset = df.loc[[i for i in range(100,200)], ['Sales', 'Profit']]
df_subset.describe()
# Out:
#              Sales       Profit
# count   100.000000   100.000000
# mean    262.957220     0.347574
# std     858.983762   170.744869
# min       1.788000 -1359.992000
# 25%      21.327000     1.635900
# 50%      66.960000     9.653600
# 75%     177.095000    23.458800
# max    8159.952000   585.552000

# %%
df_subset = df.loc[[i for i in range(100,200)],['Sales','Profit']]
df_subset
# Out:
#        Sales   Profit
# 100   95.976 -10.7973
# 101    1.788  -3.0396
# 102   23.920  11.7208
# 103  238.896 -26.8758
# 104  102.360  -3.8385
# ..       ...      ...
# 195    7.408   1.2038
# 196    6.048   1.5876
# 197   46.260  12.0276
# 198    2.946  -2.2586
# 199   16.056   5.8203
#
# [100 rows x 2 columns]

# %%
df_subset.plot.box()
plt.title("Boxplot of sales and profit", fontsize= 15)
plt.ylim(0, 500)
plt.grid(True)
plt.show()

# %%
df['State'].unique()
# Out:
# array(['Kentucky', 'California', 'Florida', 'North Carolina',
#        'Washington', 'Texas', 'Wisconsin', 'Utah', 'Nebraska',
#        'Pennsylvania', 'Illinois', 'Minnesota', 'Michigan', 'Delaware',
#        'Indiana', 'New York', 'Arizona', 'Virginia', 'Tennessee',
#        'Alabama', 'South Carolina', 'Oregon', 'Colorado', 'Iowa', 'Ohio',
#        'Missouri', 'Oklahoma', 'New Mexico', 'Louisiana', 'Connecticut',
#        'New Jersey', 'Massachusetts', 'Georgia', 'Nevada', 'Rhode Island',
#        'Mississippi', 'Arkansas', 'Montana', 'New Hampshire', 'Maryland',
#        'District of Columbia', 'Kansas', 'Vermont', 'Maine',
#        'South Dakota', 'Idaho', 'North Dakota', 'Wyoming',
#        'West Virginia'], dtype=object)

# %%
df.nunique()
# Out:
# Order ID         5009
# Order Date       1237
# Ship Date        1334
# Ship Mode           4
# Customer ID       793
# Customer Name     793
# Segment             3
# Country             1
# City              531
# State              49
# Postal Code       631
# Region              4
# Product ID       1862
# Category            3
# Sub-Category       17
# Product Name     1850
# Sales            6144
# Quantity           14
# Discount           12
# Profit           7545
# dtype: int64

# %%
df.State.nunique()
# Out:
# 49

# %%
df['Country'].unique()
# Out:
# array(['United States'], dtype=object)

# %%
df.drop('Country', axis = 1, inplace = True)

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'City', 'State', 'Postal Code', 'Region',
#        'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Sales',
#        'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df_subset = df.loc[[ i for i in range(10)], ['Ship Mode', 'State', 'Sales']]
df_subset
# Out:
#         Ship Mode       State     Sales
# 0    Second Class    Kentucky  261.9600
# 1    Second Class    Kentucky  731.9400
# 2    Second Class  California   14.6200
# 3  Standard Class     Florida  957.5775
# 4  Standard Class     Florida   22.3680
# 5  Standard Class  California   48.8600
# 6  Standard Class  California    7.2800
# 7  Standard Class  California  907.1520
# 8  Standard Class  California   18.5040
# 9  Standard Class  California  114.9000

# %%
df_subset>100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-78bbdddecb39> in <module>
# ----> 1 df_subset>100
#
# G:\anaconda\lib\site-packages\pandas\core\ops\__init__.py in f(self, other)
#     850             # straight boolean comparisons we want to allow all columns
#     851             # (regardless of dtype to pass thru) See #4537 for discussion.
# --> 852             new_data = dispatch_to_series(self, other, op)
#     853             return self._construct_result(new_data)
#     854
#
# G:\anaconda\lib\site-packages\pandas\core\ops\__init__.py in dispatch_to_series(left, right, func, str_rep, axis)
#     379         # Get the appropriate array-op to apply to each block's values.
#     380         array_op = get_array_op(func, str_rep=str_rep)
# --> 381         bm = left._data.apply(array_op, right=right)
#     382         return type(left)(bm)
#     383
#
# G:\anaconda\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, filter, **kwargs)
#     438
#     439             if callable(f):
# --> 440                 applied = b.apply(f, **kwargs)
#     441             else:
#     442                 applied = getattr(b, f)(**kwargs)
#
# G:\anaconda\lib\site-packages\pandas\core\internals\blocks.py in apply(self, func, **kwargs)
#     388         """
#     389         with np.errstate(all="ignore"):
# --> 390             result = func(self.values, **kwargs)
#     391
#     392         if is_extension_array_dtype(result) and result.ndim > 1:
#
# G:\anaconda\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     245
#     246     elif is_object_dtype(lvalues.dtype):
# --> 247         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     248
#     249     else:
#
# G:\anaconda\lib\site-packages\pandas\core\ops\array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      55         result = libops.vec_compare(x.ravel(), y, op)
#      56     else:
# ---> 57         result = libops.scalar_compare(x.ravel(), y, op)
#      58     return result.reshape(x.shape)
#      59
#
# pandas\_libs\ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
df_subset[df_subset>100]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-9f0174bef77a> in <module>
# ----> 1 df_subset[df_subset>100]
#
# G:\anaconda\lib\site-packages\pandas\core\ops\__init__.py in f(self, other)
#     850             # straight boolean comparisons we want to allow all columns
#     851             # (regardless of dtype to pass thru) See #4537 for discussion.
# --> 852             new_data = dispatch_to_series(self, other, op)
#     853             return self._construct_result(new_data)
#     854
#
# G:\anaconda\lib\site-packages\pandas\core\ops\__init__.py in dispatch_to_series(left, right, func, str_rep, axis)
#     379         # Get the appropriate array-op to apply to each block's values.
#     380         array_op = get_array_op(func, str_rep=str_rep)
# --> 381         bm = left._data.apply(array_op, right=right)
#     382         return type(left)(bm)
#     383
#
# G:\anaconda\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, filter, **kwargs)
#     438
#     439             if callable(f):
# --> 440                 applied = b.apply(f, **kwargs)
#     441             else:
#     442                 applied = getattr(b, f)(**kwargs)
#
# G:\anaconda\lib\site-packages\pandas\core\internals\blocks.py in apply(self, func, **kwargs)
#     388         """
#     389         with np.errstate(all="ignore"):
# --> 390             result = func(self.values, **kwargs)
#     391
#     392         if is_extension_array_dtype(result) and result.ndim > 1:
#
# G:\anaconda\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     245
#     246     elif is_object_dtype(lvalues.dtype):
# --> 247         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     248
#     249     else:
#
# G:\anaconda\lib\site-packages\pandas\core\ops\array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      55         result = libops.vec_compare(x.ravel(), y, op)
#      56     else:
# ---> 57         result = libops.scalar_compare(x.ravel(), y, op)
#      58     return result.reshape(x.shape)
#      59
#
# pandas\_libs\ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
df_subset[df_subset['Sales']>100]
# Out:
#         Ship Mode       State     Sales
# 0    Second Class    Kentucky  261.9600
# 1    Second Class    Kentucky  731.9400
# 3  Standard Class     Florida  957.5775
# 7  Standard Class  California  907.1520
# 9  Standard Class  California  114.9000

# %%
df_subset[(df_subset['State']!= 'California') & (df_subset['Sales']>100)]
# Out:
#         Ship Mode     State     Sales
# 0    Second Class  Kentucky  261.9600
# 1    Second Class  Kentucky  731.9400
# 3  Standard Class   Florida  957.5775

# %%
matrix_data = np.matrix('22, 66, 140;42, 70, 148;30, 62, 125;35, 68, 160;25, 62, 152')
row_labels = ['A','B','C','D','E']
column_headings = ['Age', 'Height', 'Weight']

df1 = pd.DataFrame(data= matrix_data, index= row_labels, columns=column_headings)
print("\nThe DataFrame\n", '-'*25, sep = '')
print(df1)
print("\nAfter resetting index\n",'-'*35, sep='')
print(df1.reset_index())
print("\nAfter resetting index with 'drop' option TRUE\n",'-'*45, sep='')
print(df1.reset_index(drop=True))
print("\nAdding a new column 'Profession'\n",'-'*45, sep='')
df1['Profession'] = "Student Teacher Engineer Doctor Nurse".split()
print(df1)
print("\nSetting 'Profession' column as index\n",'-'*45, sep='')
print (df1.set_index('Profession'))
# Out:
# The DataFrame
# -------------------------
#    Age  Height  Weight
# A   22      66     140
# B   42      70     148
# C   30      62     125
# D   35      68     160
# E   25      62     152
#
# After resetting index
# -----------------------------------
#   index  Age  Height  Weight
# 0     A   22      66     140
# 1     B   42      70     148
# 2     C   30      62     125
# 3     D   35      68     160
# 4     E   25      62     152
#
# After resetting index with 'drop' option TRUE
# ---------------------------------------------
#    Age  Height  Weight
# 0   22      66     140
# 1   42      70     148
# 2   30      62     125
# 3   35      68     160
# 4   25      62     152
#
# Adding a new column 'Profession'
# ---------------------------------------------
#    Age  Height  Weight Profession
# A   22      66     140    Student
# B   42      70     148    Teacher
# C   30      62     125   Engineer
# D   35      68     160     Doctor
# E   25      62     152      Nurse
#
# Setting 'Profession' column as index
# ---------------------------------------------
#             Age  Height  Weight
# Profession
# Student      22      66     140
# Teacher      42      70     148
# Engineer     30      62     125
# Doctor       35      68     160
# Nurse        25      62     152

# %%
df_subset = df.loc[[i for i in range (10)], ['Ship Mode', 'State', 'Sales']]
df_subset
# Out:
#         Ship Mode       State     Sales
# 0    Second Class    Kentucky  261.9600
# 1    Second Class    Kentucky  731.9400
# 2    Second Class  California   14.6200
# 3  Standard Class     Florida  957.5775
# 4  Standard Class     Florida   22.3680
# 5  Standard Class  California   48.8600
# 6  Standard Class  California    7.2800
# 7  Standard Class  California  907.1520
# 8  Standard Class  California   18.5040
# 9  Standard Class  California  114.9000

# %%
byState = df_subset.groupby('State')

# %%
byState

# %%
print("\nGrouping by 'State' column and listing mean sales\n", '-'*50, sep = '')
print(byState.mean())
# Out:
# Grouping by 'State' column and listing mean sales
# --------------------------------------------------
#                  Sales
# State
# California  185.219333
# Florida     489.972750
# Kentucky    496.950000

# %%
print("\nGrouping by 'State' column and listing total sum of sales\n", '-'*50,sep = '')
print(byState.sum())
# Out:
# Grouping by 'State' column and listing total sum of sales
# --------------------------------------------------
#                 Sales
# State
# California  1111.3160
# Florida      979.9455
# Kentucky     993.9000

# %%
print(pd.DataFrame(df_subset.groupby('State').describe().loc['California']).transpose())
# Out:
#            Sales
#            count        mean         std   min     25%     50%    75%      max
# California   6.0  185.219333  355.889307  7.28  15.591  33.682  98.39  907.152

# %%
df_subset.groupby('Ship Mode').describe().loc[['Second Class', 'Standard Class']]
# Out:
#                Sales                                                           \
#                count        mean         std    min      25%     50%      75%
# Ship Mode
# Second Class     3.0  336.173333  364.373037  14.62  138.290  261.96  496.950
# Standard Class   7.0  296.663071  435.947552   7.28   20.436   48.86  511.026
#
#
#                      max
# Ship Mode
# Second Class    731.9400
# Standard Class  957.5775

# %%
df_subset
# Out:
#         Ship Mode       State     Sales
# 0    Second Class    Kentucky  261.9600
# 1    Second Class    Kentucky  731.9400
# 2    Second Class  California   14.6200
# 3  Standard Class     Florida  957.5775
# 4  Standard Class     Florida   22.3680
# 5  Standard Class  California   48.8600
# 6  Standard Class  California    7.2800
# 7  Standard Class  California  907.1520
# 8  Standard Class  California   18.5040
# 9  Standard Class  California  114.9000

# %%
df_subset['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class'], dtype=object)

# %%
pd.DataFrame(byState.describe().loc['California'])
# Out:
#              California
# Sales count    6.000000
#       mean   185.219333
#       std    355.889307
#       min      7.280000
#       25%     15.591000
#       50%     33.682000
#       75%     98.390000
#       max    907.152000

# %%
byState

# %%
byStateCity = df.groupby(['State', 'City'])
byStateCity

# %%
byStateCity.describe()['Sales']
# Out:
#                       count         mean         std       min        25%  \
# State     City
# Alabama   Auburn        6.0   294.471667  361.914543     3.760     8.8050
#           Decatur      13.0   259.601538  385.660903    14.940    23.9200
#           Florence      5.0   399.470000  796.488863     4.980     7.2700
#           Hoover        4.0   131.462500  230.646923     7.160    13.3925
#           Huntsville   10.0   248.437000  419.576667     3.620    26.8700
# ...                     ...          ...         ...       ...        ...
# Wisconsin Superior      9.0   144.414444  213.394065     5.560    17.1200
#           Waukesha      1.0    54.500000         NaN    54.500    54.5000
#           Wausau        4.0    79.370000  111.450605    12.390    20.0325
#           West Allis    2.0   125.240000  165.067007     8.520    66.8800
# Wyoming   Cheyenne      1.0  1603.136000         NaN  1603.136  1603.1360
#
#                            50%        75%       max
# State     City
# Alabama   Auburn       182.030   456.4075   900.080
#           Decatur       44.950   239.9200  1215.920
#           Florence      12.480   152.7600  1819.860
#           Hoover        20.725   138.7950   477.240
#           Huntsville    81.920   171.8075  1319.960
# ...                        ...        ...       ...
# Wisconsin Superior      47.400   125.9900   629.100
#           Waukesha      54.500    54.5000    54.500
#           Wausau        29.605    88.9425   245.880
#           West Allis   125.240   183.6000   241.960
# Wyoming   Cheyenne    1603.136  1603.1360  1603.136
#
# [604 rows x 8 columns]

# %%
df_missing = pd.read_excel(r"C:\Users\hp\Desktop\New folder\Python Object and Data Structure Basics\csv file\All Files\All Files\Sample - Superstore.xls", sheet_name= "Missing")
df_missing.head(5)
# Out:
#              Customer  Product     Sales  Quantity  Discount   Profit
# 0     Brosina Hoffman      NaN  1706.184       9.0       0.2  85.3092
# 1     Brosina Hoffman   Phones   911.424       4.0       0.2  68.3568
# 2  Zuschuss Donatelli      Art     8.560       2.0       0.0   2.4824
# 3  Zuschuss Donatelli   Phones       NaN       3.0       0.2  16.0110
# 4  Zuschuss Donatelli  Binders    22.720       4.0       0.2   7.3840

# %%
df_missing.isnull()
# Out:
#     Customer  Product  Sales  Quantity  Discount  Profit
# 0      False     True  False     False     False   False
# 1      False    False  False     False     False   False
# 2      False    False  False     False     False   False
# 3      False    False   True     False     False   False
# 4      False    False  False     False     False   False
# 5      False    False  False      True     False   False
# 6      False    False  False     False     False   False
# 7      False     True  False     False     False    True
# 8       True    False  False     False     False   False
# 9      False    False  False     False     False   False
# 10     False    False  False     False     False   False

# %%
for c in df_missing.columns:
    miss = df_missing[c].isnull().sum()
    if miss>0:
        print("{} has {} missing value(s)".format(c,miss))
    else:
        print("{} has NO missing values!".format(c))
# Out:
# Customer has 1 missing value(s)
# Product has 2 missing value(s)
# Sales has 1 missing value(s)
# Quantity has 1 missing value(s)
# Discount has NO missing values!
# Profit has 1 missing value(s)

# %%
df_missing.columns
# Out:
# Index(['Customer', 'Product', 'Sales', 'Quantity', 'Discount', 'Profit'], dtype='object')

# %%
df_missing.shape
# Out:
# (11, 6)

# %%
df_missing
# Out:
#               Customer      Product     Sales  Quantity  Discount   Profit
# 0      Brosina Hoffman          NaN  1706.184       9.0       0.2  85.3092
# 1      Brosina Hoffman       Phones   911.424       4.0       0.2  68.3568
# 2   Zuschuss Donatelli          Art     8.560       2.0       0.0   2.4824
# 3   Zuschuss Donatelli       Phones       NaN       3.0       0.2  16.0110
# 4   Zuschuss Donatelli      Binders    22.720       4.0       0.2   7.3840
# 5        Eric Hoffmann      Binders    11.648       NaN       0.2   4.2224
# 6        Eric Hoffmann  Accessories    90.570       3.0       0.0  11.7741
# 7         Ruben Ausman          NaN    77.880       2.0       0.0      NaN
# 8                  NaN  Accessories    13.980       2.0       0.0   6.1512
# 9         Kunst Miller      Binders    25.824       6.0       0.2   9.3612
# 10        Kunst Miller        Paper   146.730       3.0       0.0  68.9631

# %%
df_missing.fillna('FILL')
# Out:
#               Customer      Product    Sales Quantity  Discount   Profit
# 0      Brosina Hoffman         FILL  1706.18        9       0.2  85.3092
# 1      Brosina Hoffman       Phones  911.424        4       0.2  68.3568
# 2   Zuschuss Donatelli          Art     8.56        2       0.0   2.4824
# 3   Zuschuss Donatelli       Phones     FILL        3       0.2   16.011
# 4   Zuschuss Donatelli      Binders    22.72        4       0.2    7.384
# 5        Eric Hoffmann      Binders   11.648     FILL       0.2   4.2224
# 6        Eric Hoffmann  Accessories    90.57        3       0.0  11.7741
# 7         Ruben Ausman         FILL    77.88        2       0.0     FILL
# 8                 FILL  Accessories    13.98        2       0.0   6.1512
# 9         Kunst Miller      Binders   25.824        6       0.2   9.3612
# 10        Kunst Miller        Paper   146.73        3       0.0  68.9631

# %%
df_missing[['Customer', 'Product']].fillna('FILL')
# Out:
#               Customer      Product
# 0      Brosina Hoffman         FILL
# 1      Brosina Hoffman       Phones
# 2   Zuschuss Donatelli          Art
# 3   Zuschuss Donatelli       Phones
# 4   Zuschuss Donatelli      Binders
# 5        Eric Hoffmann      Binders
# 6        Eric Hoffmann  Accessories
# 7         Ruben Ausman         FILL
# 8                 FILL  Accessories
# 9         Kunst Miller      Binders
# 10        Kunst Miller        Paper

# %%
df_missing['Sales'].fillna(method='ffill')
# Out:
# 0     1706.184
# 1      911.424
# 2        8.560
# 3        8.560
# 4       22.720
# 5       11.648
# 6       90.570
# 7       77.880
# 8       13.980
# 9       25.824
# 10     146.730
# Name: Sales, dtype: float64

# %%
df_missing['Sales'].fillna(method='bfill')
# Out:
# 0     1706.184
# 1      911.424
# 2        8.560
# 3       22.720
# 4       22.720
# 5       11.648
# 6       90.570
# 7       77.880
# 8       13.980
# 9       25.824
# 10     146.730
# Name: Sales, dtype: float64

# %%
df_missing['Sales'].fillna(df_missing.mean()['Sales'])
# Out:
# 0     1706.184
# 1      911.424
# 2        8.560
# 3      301.552
# 4       22.720
# 5       11.648
# 6       90.570
# 7       77.880
# 8       13.980
# 9       25.824
# 10     146.730
# Name: Sales, dtype: float64

# %%
df_missing.dropna(axis=0)
# Out:
#               Customer      Product    Sales  Quantity  Discount   Profit
# 1      Brosina Hoffman       Phones  911.424       4.0       0.2  68.3568
# 2   Zuschuss Donatelli          Art    8.560       2.0       0.0   2.4824
# 4   Zuschuss Donatelli      Binders   22.720       4.0       0.2   7.3840
# 6        Eric Hoffmann  Accessories   90.570       3.0       0.0  11.7741
# 9         Kunst Miller      Binders   25.824       6.0       0.2   9.3612
# 10        Kunst Miller        Paper  146.730       3.0       0.0  68.9631

# %%
df_missing.dropna(axis=1)
# Out:
#     Discount
# 0        0.2
# 1        0.2
# 2        0.0
# 3        0.2
# 4        0.2
# 5        0.2
# 6        0.0
# 7        0.0
# 8        0.0
# 9        0.2
# 10       0.0

# %%
df_missing.columns
# Out:
# Index(['Customer', 'Product', 'Sales', 'Quantity', 'Discount', 'Profit'], dtype='object')

# %%
df_missing.dropna(axis=1, thresh=10)
# Out:
#               Customer     Sales  Quantity  Discount   Profit
# 0      Brosina Hoffman  1706.184       9.0       0.2  85.3092
# 1      Brosina Hoffman   911.424       4.0       0.2  68.3568
# 2   Zuschuss Donatelli     8.560       2.0       0.0   2.4824
# 3   Zuschuss Donatelli       NaN       3.0       0.2  16.0110
# 4   Zuschuss Donatelli    22.720       4.0       0.2   7.3840
# 5        Eric Hoffmann    11.648       NaN       0.2   4.2224
# 6        Eric Hoffmann    90.570       3.0       0.0  11.7741
# 7         Ruben Ausman    77.880       2.0       0.0      NaN
# 8                  NaN    13.980       2.0       0.0   6.1512
# 9         Kunst Miller    25.824       6.0       0.2   9.3612
# 10        Kunst Miller   146.730       3.0       0.0  68.9631

# %%
df_sample = df[['Customer Name', 'State', 'Sales', 'Profit']].sample(n=50).copy()

# %%
df_sample
# Out:
#              Customer Name           State      Sales     Profit
# 4086        Linda Cazamias      California    20.9520     7.0713
# 6143          Jamie Frazer     Connecticut   119.0400    48.8064
# 429             Ross Baird  North Carolina   189.5880  -145.3508
# 2969            Jill Fjeld  North Carolina    31.1040    10.8864
# 2857    Christopher Conant  North Carolina   225.2960    22.5296
# 2323        Karen Carlisle        Kentucky    76.3000    38.1500
# 9119            Ross Baird      California    22.0500    10.5840
# 1921             Mary Zewe    Pennsylvania    15.0080     1.5008
# 1711          Jamie Kunitz      California  1702.1200   510.6360
# 881              Dave Kipp        Virginia    30.8400     8.3268
# 1085         Karen Daniels        New York  4899.9300  2400.9657
# 6887    Lauren Leatherbury      California    19.0500     8.7630
# 20      Zuschuss Donatelli      California    22.7200     7.3840
# 7579         Annie Thurman      New Jersey  2625.1200   735.0336
# 4581            Anne Pryor    Pennsylvania    25.6320     3.8448
# 9634         Toby Carlisle   Massachusetts    79.4500    22.2460
# 6061     Eugene Hildebrand        New York    14.6700     6.0147
# 8361         Trudy Schmidt           Texas     5.4320   -13.5800
# 239           Ken Lonsdale        Illinois    11.6880    -4.6752
# 6602         Odella Nelson        Maryland    15.6600     7.2036
# 2496         Bryan Spruell      California    64.1700    18.6093
# 6558         Edward Becker        New York  1522.6380   169.1820
# 6333          Xylona Preis        Michigan    29.7000    13.3650
# 9919       Muhammed Yedwab           Texas   528.4300  -143.4310
# 1700     Natalie DeCherney        New York    11.8080     4.2804
# 3668          Tim Brockman          Oregon   103.9200   -18.1860
# 6437          James Galang           Idaho   302.3760    22.6782
# 5805       Katrina Edelman           Texas   205.9992   -27.2646
# 2083          Emily Ducich           Texas    23.6800     8.8800
# 8252   Maribeth Schnelling        Illinois    60.4160     6.0416
# 3026          Meg O'Connel    Pennsylvania   254.3520     0.0000
# 2166        Helen Andreada           Texas    15.8720     1.1904
# 5609        Barry Gonzalez       Louisiana   659.9000   217.7670
# 663          Sibella Parks        New York   459.9500    18.3980
# 1251           Doug Jacobs        New York     3.2000     1.3760
# 9028     Patrick O'Donnell   Massachusetts   191.8200    61.3824
# 7775       Cynthia Delaney      California    10.9800     2.9646
# 8724         Marc Harrigan         Florida    25.3440     8.8704
# 6996      Jennifer Braxton        Illinois    13.8400   -22.1440
# 7256          Eugene Moren       Wisconsin     5.5600     1.4456
# 6152              Rob Dowd      California    87.9200     0.8792
# 1869      Charles Crestani      Washington     6.4800     3.1104
# 5475           Dean percer       Minnesota    44.4000    22.2000
# 7797           Harold Ryan        New York    47.0100    22.0947
# 2742        MaryBeth Skach      California    35.3400    13.4292
# 5306       Benjamin Venier        New York   296.3700    80.0199
# 3549      Ross DeVincentis        Kentucky    30.0000    14.4000
# 2707  Alejandro Ballentine      New Mexico   192.1600    92.2368
# 8746         Bill Overfelt      California   210.5800    12.6348
# 2840    Christine Kargatis        Virginia  1139.9200   284.9800

# %%
df_sample.shape
# Out:
# (50, 4)

# %%
df_sample['Sales'].iloc[5]=-1000.0
df_sample['Sales'].iloc[15]=-500.0
# Out:
# G:\anaconda\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_sample.plot.box()
plt.title("Boxplot of sales and profit", fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid(True)

# %%
df_1 = df[['Customer Name', 'State','Sales', 'Profit']].sample(n=4)
df_2 = df[['Customer Name', 'State', 'Sales', 'Profit']].sample(n=4)
df_3 = df[['Customer Name', 'State', 'Sales', 'Profit']].sample(n=4)

# %%
df_1
# Out:
#          Customer Name       State    Sales   Profit
# 5618  Charlotte Melton  California  443.920   8.8784
# 3610       George Bell        Ohio  177.568 -37.7332
# 3972      Janet Martin    New York   13.480   6.7400
# 6889  Saphhira Shifley     Georgia   95.680  26.7904

# %%
df_2
# Out:
#         Customer Name        State    Sales   Profit
# 4899     Sheri Gordon       Oregon   26.352 -18.4464
# 8270        Liz Preis     Illinois    9.344   3.1536
# 6680  Ted Butterfield  Connecticut   79.920  37.5624
# 747       Maya Herman   California  359.320   7.1864

# %%
df_3
# Out:
#          Customer Name         State     Sales    Profit
# 723       Mathew Reese  Pennsylvania   129.920   21.1120
# 6747      Allen Armold      New York    14.952    5.0463
# 5795    Lisa DeCherney      New York  1395.540  362.8404
# 9985  Dianna Vittorini      New York    55.600   16.1240

# %%
df
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1     CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2     CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3     US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4     US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# ...              ...        ...        ...             ...         ...
# 9989  CA-2014-110422 2014-01-21 2014-01-23    Second Class    TB-21400
# 9990  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9993  CA-2017-119914 2017-05-04 2017-05-09    Second Class    CC-12220
#
#          Customer Name    Segment             City       State  Postal Code  \
# 0          Claire Gute   Consumer        Henderson    Kentucky        42420
# 1          Claire Gute   Consumer        Henderson    Kentucky        42420
# 2      Darrin Van Huff  Corporate      Los Angeles  California        90036
# 3       Sean O'Donnell   Consumer  Fort Lauderdale     Florida        33311
# 4       Sean O'Donnell   Consumer  Fort Lauderdale     Florida        33311
# ...                ...        ...              ...         ...          ...
# 9989  Tom Boeckenhauer   Consumer            Miami     Florida        33180
# 9990       Dave Brooks   Consumer       Costa Mesa  California        92627
# 9991       Dave Brooks   Consumer       Costa Mesa  California        92627
# 9992       Dave Brooks   Consumer       Costa Mesa  California        92627
# 9993      Chris Cortes   Consumer      Westminster  California        92683
#
#      Region       Product ID         Category Sub-Category  \
# 0     South  FUR-BO-10001798        Furniture    Bookcases
# 1     South  FUR-CH-10000454        Furniture       Chairs
# 2      West  OFF-LA-10000240  Office Supplies       Labels
# 3     South  FUR-TA-10000577        Furniture       Tables
# 4     South  OFF-ST-10000760  Office Supplies      Storage
# ...     ...              ...              ...          ...
# 9989  South  FUR-FU-10001889        Furniture  Furnishings
# 9990   West  FUR-FU-10000747        Furniture  Furnishings
# 9991   West  TEC-PH-10003645       Technology       Phones
# 9992   West  OFF-PA-10004041  Office Supplies        Paper
# 9993   West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name     Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                        Eldon Fold 'N Roll Cart System   22.3680         2
# ...                                                 ...       ...       ...
# 9989                             Ultra Door Pull Handle   25.2480         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600         2
# 9991                              Aastra 57i VoIP phone  258.5760         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 19 columns]

# %%
df_cat1 = pd.concat([df_1, df_2, df_3], axis= 0)
df_cat1
# Out:
#          Customer Name         State     Sales    Profit
# 5618  Charlotte Melton    California   443.920    8.8784
# 3610       George Bell          Ohio   177.568  -37.7332
# 3972      Janet Martin      New York    13.480    6.7400
# 6889  Saphhira Shifley       Georgia    95.680   26.7904
# 4899      Sheri Gordon        Oregon    26.352  -18.4464
# 8270         Liz Preis      Illinois     9.344    3.1536
# 6680   Ted Butterfield   Connecticut    79.920   37.5624
# 747        Maya Herman    California   359.320    7.1864
# 723       Mathew Reese  Pennsylvania   129.920   21.1120
# 6747      Allen Armold      New York    14.952    5.0463
# 5795    Lisa DeCherney      New York  1395.540  362.8404
# 9985  Dianna Vittorini      New York    55.600   16.1240

# %%
df_cat1.shape
# Out:
# (12, 4)

# %%
df_cat2 = pd.concat([df_1, df_2, df_3], axis= 1)
df_cat2
# Out:
#          Customer Name       State    Sales   Profit    Customer Name  \
# 723                NaN         NaN      NaN      NaN              NaN
# 747                NaN         NaN      NaN      NaN      Maya Herman
# 3610       George Bell        Ohio  177.568 -37.7332              NaN
# 3972      Janet Martin    New York   13.480   6.7400              NaN
# 4899               NaN         NaN      NaN      NaN     Sheri Gordon
# 5618  Charlotte Melton  California  443.920   8.8784              NaN
# 5795               NaN         NaN      NaN      NaN              NaN
# 6680               NaN         NaN      NaN      NaN  Ted Butterfield
# 6747               NaN         NaN      NaN      NaN              NaN
# 6889  Saphhira Shifley     Georgia   95.680  26.7904              NaN
# 8270               NaN         NaN      NaN      NaN        Liz Preis
# 9985               NaN         NaN      NaN      NaN              NaN
#
#             State    Sales   Profit     Customer Name         State     Sales  \
# 723           NaN      NaN      NaN      Mathew Reese  Pennsylvania   129.920
# 747    California  359.320   7.1864               NaN           NaN       NaN
# 3610          NaN      NaN      NaN               NaN           NaN       NaN
# 3972          NaN      NaN      NaN               NaN           NaN       NaN
# 4899       Oregon   26.352 -18.4464               NaN           NaN       NaN
# 5618          NaN      NaN      NaN               NaN           NaN       NaN
# 5795          NaN      NaN      NaN    Lisa DeCherney      New York  1395.540
# 6680  Connecticut   79.920  37.5624               NaN           NaN       NaN
# 6747          NaN      NaN      NaN      Allen Armold      New York    14.952
# 6889          NaN      NaN      NaN               NaN           NaN       NaN
# 8270     Illinois    9.344   3.1536               NaN           NaN       NaN
# 9985          NaN      NaN      NaN  Dianna Vittorini      New York    55.600
#
#         Profit
# 723    21.1120
# 747        NaN
# 3610       NaN
# 3972       NaN
# 4899       NaN
# 5618       NaN
# 5795  362.8404
# 6680       NaN
# 6747    5.0463
# 6889       NaN
# 8270       NaN
# 9985   16.1240

# %%
df_cat2.shape
# Out:
# (12, 12)

# %%
df_1 = df[['Customer Name', 'Ship Date', 'Ship Mode']][0:4]
df_1
# Out:
#      Customer Name  Ship Date       Ship Mode
# 0      Claire Gute 2016-11-11    Second Class
# 1      Claire Gute 2016-11-11    Second Class
# 2  Darrin Van Huff 2016-06-16    Second Class
# 3   Sean O'Donnell 2015-10-18  Standard Class

# %%
df_2 = df[['Customer Name', 'Product Name', 'Quantity']][0:4]
df_2
# Out:
#      Customer Name                                       Product Name  \
# 0      Claire Gute                  Bush Somerset Collection Bookcase
# 1      Claire Gute  Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2  Darrin Van Huff  Self-Adhesive Address Labels for Typewriters b...
# 3   Sean O'Donnell      Bretford CR4500 Series Slim Rectangular Table
#
#    Quantity
# 0         2
# 1         3
# 2         2
# 3         5

# %%
pd.merge(df_1, df_2, on= 'Customer Name', how = 'inner').drop_duplicates()
# Out:
#      Customer Name  Ship Date       Ship Mode  \
# 0      Claire Gute 2016-11-11    Second Class
# 1      Claire Gute 2016-11-11    Second Class
# 4  Darrin Van Huff 2016-06-16    Second Class
# 5   Sean O'Donnell 2015-10-18  Standard Class
#
#                                         Product Name  Quantity
# 0                  Bush Somerset Collection Bookcase         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...         3
# 4  Self-Adhesive Address Labels for Typewriters b...         2
# 5      Bretford CR4500 Series Slim Rectangular Table         5

# %%
pd.merge(df_1, df_2, on = 'Customer Name', how = 'inner')
# Out:
#      Customer Name  Ship Date       Ship Mode  \
# 0      Claire Gute 2016-11-11    Second Class
# 1      Claire Gute 2016-11-11    Second Class
# 2      Claire Gute 2016-11-11    Second Class
# 3      Claire Gute 2016-11-11    Second Class
# 4  Darrin Van Huff 2016-06-16    Second Class
# 5   Sean O'Donnell 2015-10-18  Standard Class
#
#                                         Product Name  Quantity
# 0                  Bush Somerset Collection Bookcase         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...         3
# 2                  Bush Somerset Collection Bookcase         2
# 3  Hon Deluxe Fabric Upholstered Stacking Chairs,...         3
# 4  Self-Adhesive Address Labels for Typewriters b...         2
# 5      Bretford CR4500 Series Slim Rectangular Table         5

# %%
df_3 = df[['Customer Name', 'Product Name', 'Quantity']][2:6]
df_3
# Out:
#      Customer Name                                       Product Name  \
# 2  Darrin Van Huff  Self-Adhesive Address Labels for Typewriters b...
# 3   Sean O'Donnell      Bretford CR4500 Series Slim Rectangular Table
# 4   Sean O'Donnell                     Eldon Fold 'N Roll Cart System
# 5  Brosina Hoffman  Eldon Expressions Wood and Plastic Desk Access...
#
#    Quantity
# 2         2
# 3         5
# 4         2
# 5         7

# %%
pd.merge(df_1, df_3, on = 'Customer Name', how = 'outer').drop_duplicates()
# Out:
#      Customer Name  Ship Date       Ship Mode  \
# 0      Claire Gute 2016-11-11    Second Class
# 2  Darrin Van Huff 2016-06-16    Second Class
# 3   Sean O'Donnell 2015-10-18  Standard Class
# 4   Sean O'Donnell 2015-10-18  Standard Class
# 5  Brosina Hoffman        NaT             NaN
#
#                                         Product Name  Quantity
# 0                                                NaN       NaN
# 2  Self-Adhesive Address Labels for Typewriters b...       2.0
# 3      Bretford CR4500 Series Slim Rectangular Table       5.0
# 4                     Eldon Fold 'N Roll Cart System       2.0
# 5  Eldon Expressions Wood and Plastic Desk Access...       7.0

# %%
df_1 = df[['Customer Name', 'Ship Date', 'Ship Mode']][0:4]
df_1.set_index(['Customer Name'], inplace = True)
df_1
# Out:
#                  Ship Date       Ship Mode
# Customer Name
# Claire Gute     2016-11-11    Second Class
# Claire Gute     2016-11-11    Second Class
# Darrin Van Huff 2016-06-16    Second Class
# Sean O'Donnell  2015-10-18  Standard Class

# %%
df_2= df[['Customer Name', 'Product Name', 'Quantity']][2:6]
df_2.set_index(['Customer Name'], inplace= True)
df_2
# Out:
#                                                       Product Name  Quantity
# Customer Name
# Darrin Van Huff  Self-Adhesive Address Labels for Typewriters b...         2
# Sean O'Donnell       Bretford CR4500 Series Slim Rectangular Table         5
# Sean O'Donnell                      Eldon Fold 'N Roll Cart System         2
# Brosina Hoffman  Eldon Expressions Wood and Plastic Desk Access...         7

# %%
df_1.join(df_2, how= 'left').drop_duplicates()
# Out:
#                  Ship Date       Ship Mode  \
# Customer Name
# Claire Gute     2016-11-11    Second Class
# Darrin Van Huff 2016-06-16    Second Class
# Sean O'Donnell  2015-10-18  Standard Class
# Sean O'Donnell  2015-10-18  Standard Class
#
#                                                       Product Name  Quantity
# Customer Name
# Claire Gute                                                    NaN       NaN
# Darrin Van Huff  Self-Adhesive Address Labels for Typewriters b...       2.0
# Sean O'Donnell       Bretford CR4500 Series Slim Rectangular Table       5.0
# Sean O'Donnell                      Eldon Fold 'N Roll Cart System       2.0

# %%
df_1
# Out:
#                  Ship Date       Ship Mode
# Customer Name
# Claire Gute     2016-11-11    Second Class
# Claire Gute     2016-11-11    Second Class
# Darrin Van Huff 2016-06-16    Second Class
# Sean O'Donnell  2015-10-18  Standard Class

# %%
df_2
# Out:
#                                                       Product Name  Quantity
# Customer Name
# Darrin Van Huff  Self-Adhesive Address Labels for Typewriters b...         2
# Sean O'Donnell       Bretford CR4500 Series Slim Rectangular Table         5
# Sean O'Donnell                      Eldon Fold 'N Roll Cart System         2
# Brosina Hoffman  Eldon Expressions Wood and Plastic Desk Access...         7

# %%
df_1.join(df_2, how = 'inner').drop_duplicates()
# Out:
#                  Ship Date       Ship Mode  \
# Customer Name
# Darrin Van Huff 2016-06-16    Second Class
# Sean O'Donnell  2015-10-18  Standard Class
# Sean O'Donnell  2015-10-18  Standard Class
#
#                                                       Product Name  Quantity
# Customer Name
# Darrin Van Huff  Self-Adhesive Address Labels for Typewriters b...         2
# Sean O'Donnell       Bretford CR4500 Series Slim Rectangular Table         5
# Sean O'Donnell                      Eldon Fold 'N Roll Cart System         2

# %%
df_1.join(df_2, how= 'outer').drop_duplicates()
# Out:
#                  Ship Date       Ship Mode  \
# Customer Name
# Brosina Hoffman        NaT             NaN
# Claire Gute     2016-11-11    Second Class
# Darrin Van Huff 2016-06-16    Second Class
# Sean O'Donnell  2015-10-18  Standard Class
# Sean O'Donnell  2015-10-18  Standard Class
#
#                                                       Product Name  Quantity
# Customer Name
# Brosina Hoffman  Eldon Expressions Wood and Plastic Desk Access...       7.0
# Claire Gute                                                    NaN       NaN
# Darrin Van Huff  Self-Adhesive Address Labels for Typewriters b...       2.0
# Sean O'Donnell       Bretford CR4500 Series Slim Rectangular Table       5.0
# Sean O'Donnell                      Eldon Fold 'N Roll Cart System       2.0

# %%
df_1.join(df_2, how= 'outer').drop_duplicates()
# Out:
#                  Ship Date       Ship Mode  \
# Customer Name
# Brosina Hoffman        NaT             NaN
# Claire Gute     2016-11-11    Second Class
# Darrin Van Huff 2016-06-16    Second Class
# Sean O'Donnell  2015-10-18  Standard Class
# Sean O'Donnell  2015-10-18  Standard Class
#
#                                                       Product Name  Quantity
# Customer Name
# Brosina Hoffman  Eldon Expressions Wood and Plastic Desk Access...       7.0
# Claire Gute                                                    NaN       NaN
# Darrin Van Huff  Self-Adhesive Address Labels for Typewriters b...       2.0
# Sean O'Donnell       Bretford CR4500 Series Slim Rectangular Table       5.0
# Sean O'Donnell                      Eldon Fold 'N Roll Cart System       2.0

# %%
df_sample(n=5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-472ba8d8a73e> in <module>
# ----> 1 df_sample(n=5)
#
# TypeError: 'DataFrame' object is not callable

# %%
df
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1     CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2     CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3     US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4     US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# ...              ...        ...        ...             ...         ...
# 9989  CA-2014-110422 2014-01-21 2014-01-23    Second Class    TB-21400
# 9990  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9993  CA-2017-119914 2017-05-04 2017-05-09    Second Class    CC-12220
#
#          Customer Name    Segment             City       State  Postal Code  \
# 0          Claire Gute   Consumer        Henderson    Kentucky        42420
# 1          Claire Gute   Consumer        Henderson    Kentucky        42420
# 2      Darrin Van Huff  Corporate      Los Angeles  California        90036
# 3       Sean O'Donnell   Consumer  Fort Lauderdale     Florida        33311
# 4       Sean O'Donnell   Consumer  Fort Lauderdale     Florida        33311
# ...                ...        ...              ...         ...          ...
# 9989  Tom Boeckenhauer   Consumer            Miami     Florida        33180
# 9990       Dave Brooks   Consumer       Costa Mesa  California        92627
# 9991       Dave Brooks   Consumer       Costa Mesa  California        92627
# 9992       Dave Brooks   Consumer       Costa Mesa  California        92627
# 9993      Chris Cortes   Consumer      Westminster  California        92683
#
#      Region       Product ID         Category Sub-Category  \
# 0     South  FUR-BO-10001798        Furniture    Bookcases
# 1     South  FUR-CH-10000454        Furniture       Chairs
# 2      West  OFF-LA-10000240  Office Supplies       Labels
# 3     South  FUR-TA-10000577        Furniture       Tables
# 4     South  OFF-ST-10000760  Office Supplies      Storage
# ...     ...              ...              ...          ...
# 9989  South  FUR-FU-10001889        Furniture  Furnishings
# 9990   West  FUR-FU-10000747        Furniture  Furnishings
# 9991   West  TEC-PH-10003645       Technology       Phones
# 9992   West  OFF-PA-10004041  Office Supplies        Paper
# 9993   West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name     Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                        Eldon Fold 'N Roll Cart System   22.3680         2
# ...                                                 ...       ...       ...
# 9989                             Ultra Door Pull Handle   25.2480         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600         2
# 9991                              Aastra 57i VoIP phone  258.5760         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 19 columns]

# %%
df.sample(n=5)
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 775   CA-2017-104220 2017-01-30 2017-02-05  Standard Class    BV-11245
# 1203  CA-2016-114727 2016-07-18 2016-07-24  Standard Class    LS-16945
# 1329  CA-2016-142762 2016-05-23 2016-05-27  Standard Class    LD-17005
# 2575  CA-2014-129091 2014-11-22 2014-11-27  Standard Class    RA-19885
# 7255  CA-2016-152730 2016-05-30 2016-06-04  Standard Class    EM-14140
#
#          Customer Name      Segment           City       State  Postal Code  \
# 775    Benjamin Venier    Corporate     Des Moines        Iowa        50315
# 1203  Linda Southworth    Corporate         Denver    Colorado        80219
# 1329    Lisa DeCherney     Consumer  San Francisco  California        94109
# 2575      Ruben Ausman    Corporate       Columbus     Georgia        31907
# 7255      Eugene Moren  Home Office       Superior   Wisconsin        54880
#
#        Region       Product ID         Category Sub-Category  \
# 775   Central  FUR-FU-10002597        Furniture  Furnishings
# 1203     West  OFF-ST-10002292  Office Supplies      Storage
# 1329     West  FUR-FU-10003691        Furniture  Furnishings
# 2575    South  OFF-BI-10001071  Office Supplies      Binders
# 7255  Central  OFF-ST-10000876  Office Supplies      Storage
#
#                                            Product Name    Sales  Quantity  \
# 775   C-Line Magnetic Cubicle Keepers, Clear Polypro...   34.580         7
# 1203  Sauder Facets Collection Locker/File Cabinet, ...  593.568         2
# 1329         Eldon Image Series Desk Accessories, Ebony   37.050         3
# 2575                  GBC ProClick Punch Binding System  319.900         5
# 7255                        Eldon Simplefile Box Office   49.760         4
#
#       Discount    Profit
# 775        0.0   14.5236
# 1203       0.2    0.0000
# 1329       0.0   16.3020
# 2575       0.0  156.7510
# 7255       0.0   13.9328

# %%
df.sample(frac=0.001)
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 1807  US-2016-116729 2016-12-25 2016-12-28     First Class    GK-14620
# 4936  CA-2017-150931 2017-01-06 2017-01-13  Standard Class    DP-13390
# 3216  CA-2014-114433 2014-05-13 2014-05-17  Standard Class    NP-18325
# 293   CA-2014-111451 2014-12-26 2014-12-28     First Class    KL-16555
# 4428  CA-2017-119452 2017-03-21 2017-03-27  Standard Class    CL-12565
# 484   CA-2017-140963 2017-06-10 2017-06-13     First Class    MT-18070
# 3268  CA-2014-143840 2014-05-22 2014-05-29  Standard Class    EH-14185
# 1417  CA-2015-126697 2015-09-21 2015-09-24     First Class    SV-20815
# 9939  CA-2016-169824 2016-12-12 2016-12-17  Standard Class    NS-18640
# 9526  CA-2017-156958 2017-12-05 2017-12-06     First Class    PB-18805
#
#         Customer Name      Segment              City       State  Postal Code  \
# 1807      Grace Kelly    Corporate       Los Angeles  California        90049
# 4936    Dennis Pardue  Home Office        Tuscaloosa     Alabama        35401
# 3216     Naresj Patel     Consumer           Oakland  California        94601
# 293     Kelly Lampkin    Corporate  Colorado Springs    Colorado        80906
# 4428      Clay Ludtke     Consumer             Tulsa    Oklahoma        74133
# 484     Michelle Tran  Home Office       Los Angeles  California        90045
# 3268       Evan Henry     Consumer           Decatur     Alabama        35601
# 1417       Stuart Van    Corporate           Houston       Texas        77041
# 9939     Noel Staavos    Corporate     New York City    New York        10009
# 9526  Patrick Bzostek  Home Office           Seattle  Washington        98115
#
#        Region       Product ID         Category Sub-Category  \
# 1807     West  TEC-AC-10001465       Technology  Accessories
# 4936    South  OFF-BI-10004728  Office Supplies      Binders
# 3216     West  TEC-AC-10002800       Technology  Accessories
# 293      West  FUR-FU-10004091        Furniture  Furnishings
# 4428  Central  FUR-CH-10004495        Furniture       Chairs
# 484      West  OFF-LA-10003923  Office Supplies       Labels
# 3268    South  TEC-PH-10003171       Technology       Phones
# 1417  Central  TEC-AC-10004353       Technology  Accessories
# 9939     East  OFF-SU-10000952  Office Supplies     Supplies
# 9526     West  TEC-PH-10000148       Technology       Phones
#
#                                            Product Name     Sales  Quantity  \
# 1807               SanDisk Cruzer 64 GB USB Flash Drive   254.240         7
# 4936  Wilson Jones Turn Tabs Binder Tool for Ring Bi...    33.740         7
# 3216           Plantronics Audio 478 Stereo USB Headset   149.970         3
# 293   Howard Miller 13" Diameter Goldtone Round Wall...   300.416         8
# 4428      Global Leather and Oak Executive Chair, Black  1805.880         6
# 484              Alphabetical Labels for Top Tab Filing    29.600         2
# 3268     Plantronics Encore H101 Dual Earpieces Headset    44.950         1
# 1417                              Hypercom P1300 Pinpad   151.200         3
# 9939                     Fiskars Home & Office Scissors    35.520         4
# 9526  Cyber Acoustics AC-202b Speech Recognition Ste...    31.176         3
#
#       Discount    Profit
# 1807       0.0   76.2720
# 4936       0.0   15.5204
# 3216       0.0   52.4895
# 293        0.2   78.8592
# 4428       0.0  523.7052
# 484        0.0   14.8000
# 3268       0.0   12.5860
# 1417       0.2   32.1300
# 9939       0.0    9.9456
# 9526       0.2   -7.0146

# %%
df.sample(frac=0.001, replace=True)
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 3002  CA-2015-130610 2015-07-05 2015-07-10  Standard Class    VP-21730
# 5872  CA-2017-129910 2017-03-30 2017-04-03  Standard Class    ME-17320
# 3312  US-2014-133130 2014-09-27 2014-10-01  Standard Class    TH-21100
# 6152  CA-2017-139437 2017-07-03 2017-07-08  Standard Class    RD-19585
# 2912  CA-2014-113929 2014-06-16 2014-06-21  Standard Class    CK-12205
# 3472  CA-2017-122644 2017-11-12 2017-11-17  Standard Class    SF-20965
# 8646  CA-2016-113341 2016-11-25 2016-11-29  Standard Class    MH-17455
# 9840  US-2016-125402 2016-09-25 2016-10-01  Standard Class    DL-12865
# 1933  CA-2017-161200 2017-08-06 2017-08-10    Second Class    SV-20365
# 1025  CA-2016-126529 2016-01-11 2016-01-13    Second Class    DE-13255
#
#             Customer Name      Segment              City       State  \
# 3002         Victor Preis  Home Office  Sterling Heights    Michigan
# 5872        Maria Etezadi  Home Office          Columbus     Georgia
# 3312       Thea Hendricks     Consumer         San Diego  California
# 6152             Rob Dowd     Consumer       Los Angeles  California
# 2912  Chloris Kastensmidt     Consumer         Hempstead    New York
# 3472      Sylvia Foulston    Corporate          Columbus        Ohio
# 8646        Mark Hamilton     Consumer       Los Angeles  California
# 9840           Dan Lawera     Consumer        Long Beach  California
# 1933          Seth Vernon     Consumer         Lafayette   Louisiana
# 1025           Deanra Eno  Home Office       Springfield        Ohio
#
#       Postal Code   Region       Product ID         Category Sub-Category  \
# 3002        48310  Central  OFF-BI-10003655  Office Supplies      Binders
# 5872        31907    South  OFF-ST-10003282  Office Supplies      Storage
# 3312        92037     West  FUR-CH-10002602        Furniture       Chairs
# 6152        90004     West  OFF-ST-10002485  Office Supplies      Storage
# 2912        11550     East  OFF-AR-10003772  Office Supplies          Art
# 3472        43229     East  TEC-AC-10003614       Technology  Accessories
# 8646        90032     West  FUR-CH-10004698        Furniture       Chairs
# 9840        90805     West  TEC-PH-10003356       Technology       Phones
# 1933        70506    South  FUR-FU-10001706        Furniture  Furnishings
# 1025        45503     East  OFF-PA-10001166  Office Supplies        Paper
#
#                                            Product Name    Sales  Quantity  \
# 3002                         Durable Pressboard Binders   19.000         5
# 5872  Advantus 10-Drawer Portable Organizer, Chrome ...   59.760         1
# 3312  DMI Arturo Collection Mission-style Design Woo...  603.920         5
# 6152                           Rogers Deluxe File Chest   87.920         4
# 2912  Boston 16750 Black Compact Battery Pencil Shar...   35.000         4
# 3472  Verbatim 25 GB 6x Blu-ray Single Layer Recorda...   18.544         2
# 8646             Padded Folding Chairs, Black, 4/Carton  194.352         3
# 9840   SmartStand Mobile Device Holder, Assorted Colors   44.736         8
# 1933                       Longer-Life Soft White Bulbs   15.400         5
# 1025                                            Xerox 2   15.552         3
#
#       Discount   Profit
# 3002       0.0   8.9300
# 5872       0.0  16.7328
# 3312       0.2  45.2940
# 6152       0.0   0.8792
# 2912       0.0  10.5000
# 3472       0.2   3.0134
# 8646       0.2  19.4352
# 9840       0.2   4.4736
# 1933       0.0   7.3920
# 1025       0.2   5.4432

# %%
df['Customer Name'].value_counts()[:10]
# Out:
# William Brown          37
# Paul Prost             34
# John Lee               34
# Matt Abelman           34
# Chloris Kastensmidt    32
# Jonathan Doherty       32
# Seth Vernon            32
# Edward Hooks           32
# Zuschuss Carroll       31
# Arthur Prichep         31
# Name: Customer Name, dtype: int64

# %%
df_sample = df.sample(n=100)

# %%
df_sample
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 917   US-2014-141215 2014-06-15 2014-06-21  Standard Class    KL-16555
# 6700  CA-2017-145429 2017-07-21 2017-07-25  Standard Class    SW-20455
# 4686  CA-2016-159912 2016-08-29 2016-09-03  Standard Class    GB-14530
# 2898  US-2015-114839 2015-04-26 2015-04-30  Standard Class    PW-19240
# 1345  CA-2014-118339 2014-03-17 2014-03-24  Standard Class    BN-11515
# ...              ...        ...        ...             ...         ...
# 3413  CA-2016-100244 2016-09-20 2016-09-24  Standard Class    GM-14695
# 3279  CA-2014-102988 2014-04-05 2014-04-09    Second Class    GM-14695
# 2242  CA-2017-103380 2017-11-21 2017-11-25  Standard Class    BF-11005
# 7258  CA-2016-152730 2016-05-30 2016-06-04  Standard Class    EM-14140
# 8825  CA-2015-115399 2015-12-19 2015-12-22     First Class    AG-10900
#
#        Customer Name      Segment           City         State  Postal Code  \
# 917    Kelly Lampkin    Corporate    San Antonio         Texas        78207
# 6700     Shaun Weien     Consumer      San Diego    California        92024
# 4686     George Bell    Corporate   Philadelphia  Pennsylvania        19120
# 2898    Pierre Wener     Consumer        Houston         Texas        77036
# 1345  Bradley Nguyen     Consumer      Lakeville     Minnesota        55044
# ...              ...          ...            ...           ...          ...
# 3413    Greg Maxwell    Corporate  San Francisco    California        94122
# 3279    Greg Maxwell    Corporate     Alexandria      Virginia        22304
# 2242     Barry Franz  Home Office       Pasadena    California        91104
# 7258    Eugene Moren  Home Office       Superior     Wisconsin        54880
# 8825   Arthur Gainer     Consumer   Philadelphia  Pennsylvania        19134
#
#        Region       Product ID         Category Sub-Category  \
# 917   Central  OFF-BI-10002706  Office Supplies      Binders
# 6700     West  OFF-BI-10001524  Office Supplies      Binders
# 4686     East  OFF-FA-10000053  Office Supplies    Fasteners
# 2898  Central  FUR-CH-10004086        Furniture       Chairs
# 1345  Central  OFF-AP-10001154  Office Supplies   Appliances
# ...       ...              ...              ...          ...
# 3413     West  OFF-PA-10002319  Office Supplies        Paper
# 3279    South  OFF-AR-10000127  Office Supplies          Art
# 2242     West  OFF-ST-10003442  Office Supplies      Storage
# 7258  Central  OFF-AR-10000940  Office Supplies          Art
# 8825     East  OFF-LA-10003190  Office Supplies       Labels
#
#                                            Product Name    Sales  Quantity  \
# 917   Avery Premier Heavy-Duty Binder with Round Loc...    8.568         3
# 6700  GBC Premium Transparent Covers with Diagonal L...   50.352         3
# 4686                Revere Boxed Rubber Bands by Revere   10.584         7
# 2898  Hon 4070 Series Pagoda Armless Upholstered Sta...  408.422         2
# 1345   Bionaire Personal Warm Mist Humidifier/Vaporizer   93.780         2
# ...                                                 ...      ...       ...
# 3413                                         Xerox 1944   77.520         2
# 3279                                         Newell 321   22.960         7
# 2242                      Eldon Portable Mobile Manager   56.560         2
# 7258                                         Newell 343   14.700         5
# 8825                                          Avery 474    6.912         3
#
#       Discount   Profit
# 917        0.8 -14.5656
# 6700       0.2  17.6232
# 4686       0.2  -2.3814
# 2898       0.3  -5.8346
# 1345       0.0  36.5742
# ...        ...      ...
# 3413       0.0  37.9848
# 3279       0.0   6.6584
# 2242       0.0  15.2712
# 7258       0.0   3.9690
# 8825       0.2   2.5056
#
# [100 rows x 19 columns]

# %%
df_sample.pivot_table(values= ['Sales', 'Quantity', 'Profit'], index= ['Region', 'State'], aggfunc= 'mean')
# Out:
#                              Profit   Quantity        Sales
# Region  State
# Central Illinois          29.837550   5.500000   328.372000
#         Indiana            0.000000   3.000000     5.940000
#         Michigan          31.024633   3.333333   101.523333
#         Minnesota         36.574200   2.000000    93.780000
#         Nebraska          54.868550   5.500000   201.065000
#         Oklahoma         108.125333   4.000000   729.613333
#         Texas            -12.600623   2.461538   127.611692
#         Wisconsin        113.627250   5.000000   392.325000
# East    Massachusetts     73.064600   3.500000   280.030000
#         New Jersey        19.393800   4.500000    55.680000
#         New York          50.499482   3.090909   245.462909
#         Ohio             -40.119440   4.000000   291.213600
#         Pennsylvania      14.359800   4.000000   124.974000
#         Rhode Island      11.117600   1.000000    42.760000
#         Vermont          406.715400  13.000000  1564.290000
# South   Arkansas          10.189350   6.000000    23.520000
#         Florida          -13.494700   5.000000    28.530000
#         Kentucky          96.193650   2.500000   375.385000
#         Louisiana        217.767000   2.000000   659.900000
#         Mississippi       42.218000   5.000000   112.670000
#         North Carolina    48.898433   5.333333   396.642667
#         Tennessee       -646.217100   4.500000   916.467000
#         Virginia          31.604200   5.000000    68.030000
# West    Arizona         -448.896000   5.000000   801.600000
#         California        17.153029   3.047619    52.740857
#         Nevada            24.998000   5.000000    86.200000
#         Utah               7.945000   5.000000   158.900000
#         Washington      1028.015000   5.000000  2467.846857

# %%
df_sample = df[['Customer Name', 'State', 'Sales', 'Quantity']].sample(n=15)
df_sample
# Out:
#         Customer Name           State     Sales  Quantity
# 5029   Vivek Gonzalez      California     8.340         3
# 9124     Matt Abelman           Texas     9.552         3
# 432        Ross Baird  North Carolina     4.768         2
# 6501     Liz Carlisle            Ohio   539.964         6
# 3845     Todd Sumrall      California   616.998         6
# 4387     Bart Pistole      California    25.032         3
# 8303   Nancy Lomonaco      California    73.584         2
# 5539  Laurel Elliston        Illinois   181.986         2
# 8333     Pamela Stobb   Massachusetts    17.940         3
# 4841     Neoma Murray            Ohio     5.553         3
# 3118          Jim Epp         Florida  1123.920         5
# 7002     David Wiener      California   289.240         7
# 1679     Sean Braxton    Pennsylvania    32.382         3
# 5032    Brenda Bowman      New Jersey   212.940         3
# 2189      Ivan Liston         Indiana  1454.490         9

# %%
df_sample.sort_values(by= 'Sales')
# Out:
#         Customer Name           State     Sales  Quantity
# 432        Ross Baird  North Carolina     4.768         2
# 4841     Neoma Murray            Ohio     5.553         3
# 5029   Vivek Gonzalez      California     8.340         3
# 9124     Matt Abelman           Texas     9.552         3
# 8333     Pamela Stobb   Massachusetts    17.940         3
# 4387     Bart Pistole      California    25.032         3
# 1679     Sean Braxton    Pennsylvania    32.382         3
# 8303   Nancy Lomonaco      California    73.584         2
# 5539  Laurel Elliston        Illinois   181.986         2
# 5032    Brenda Bowman      New Jersey   212.940         3
# 7002     David Wiener      California   289.240         7
# 6501     Liz Carlisle            Ohio   539.964         6
# 3845     Todd Sumrall      California   616.998         6
# 3118          Jim Epp         Florida  1123.920         5
# 2189      Ivan Liston         Indiana  1454.490         9

# %%
df_sample.sort_values(by = ['State', 'Sales'])
# Out:
#         Customer Name           State     Sales  Quantity
# 5029   Vivek Gonzalez      California     8.340         3
# 4387     Bart Pistole      California    25.032         3
# 8303   Nancy Lomonaco      California    73.584         2
# 7002     David Wiener      California   289.240         7
# 3845     Todd Sumrall      California   616.998         6
# 3118          Jim Epp         Florida  1123.920         5
# 5539  Laurel Elliston        Illinois   181.986         2
# 2189      Ivan Liston         Indiana  1454.490         9
# 8333     Pamela Stobb   Massachusetts    17.940         3
# 5032    Brenda Bowman      New Jersey   212.940         3
# 432        Ross Baird  North Carolina     4.768         2
# 4841     Neoma Murray            Ohio     5.553         3
# 6501     Liz Carlisle            Ohio   539.964         6
# 1679     Sean Braxton    Pennsylvania    32.382         3
# 9124     Matt Abelman           Texas     9.552         3

# %%
def categorize_sales(price):
    if price < 50:
        return "Low"
    elif price < 200:
        return "Medium"
    else:
        return "High"

# %%
df_sample = df[['Customer Name', 'State', 'Sales']].sample(n=100)
df_sample.head(10)
# Out:
#             Customer Name          State    Sales
# 3045          Chuck Clark      Minnesota   13.900
# 1602      Cynthia Arntzen      Tennessee    6.672
# 388         Nathan Gelder           Ohio    2.624
# 141         Sally Hughsby     California    8.820
# 9619         Bill Stewart           Ohio  139.960
# 1273        Maurice Satty          Texas   10.368
# 7263  Marina Lichtenstein   Pennsylvania   31.680
# 1377    Valerie Dominguez           Utah   16.400
# 8394           Eva Jacobs  Massachusetts  901.950
# 9971          Mark Packer        Georgia  140.750

# %%
df_sample['Customer Name Length']= df_sample['Customer Name'].apply(len)
df_sample.head(10)
# Out:
#             Customer Name          State    Sales  Customer Name Length
# 3045          Chuck Clark      Minnesota   13.900                    11
# 1602      Cynthia Arntzen      Tennessee    6.672                    15
# 388         Nathan Gelder           Ohio    2.624                    13
# 141         Sally Hughsby     California    8.820                    13
# 9619         Bill Stewart           Ohio  139.960                    12
# 1273        Maurice Satty          Texas   10.368                    13
# 7263  Marina Lichtenstein   Pennsylvania   31.680                    19
# 1377    Valerie Dominguez           Utah   16.400                    17
# 8394           Eva Jacobs  Massachusetts  901.950                    10
# 9971          Mark Packer        Georgia  140.750                    11

# %%
df_sample[['Customer Name'], ['Chuck Clark']].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-106-aac3d241f568> in <module>
# ----> 1 df_sample[['Customer Name'], ['Chuck Clark']].value_counts()
#
# G:\anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# G:\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2644                 )
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#    2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(['Customer Name'], ['Chuck Clark'])' is an invalid key

# %%
df_sample['Discounted Price'] = df_sample['Sales'].apply(lambda x:0.85*x if x>200 else x)
df_sample.head(10)
# Out:
#             Customer Name          State    Sales  Customer Name Length  \
# 3045          Chuck Clark      Minnesota   13.900                    11
# 1602      Cynthia Arntzen      Tennessee    6.672                    15
# 388         Nathan Gelder           Ohio    2.624                    13
# 141         Sally Hughsby     California    8.820                    13
# 9619         Bill Stewart           Ohio  139.960                    12
# 1273        Maurice Satty          Texas   10.368                    13
# 7263  Marina Lichtenstein   Pennsylvania   31.680                    19
# 1377    Valerie Dominguez           Utah   16.400                    17
# 8394           Eva Jacobs  Massachusetts  901.950                    10
# 9971          Mark Packer        Georgia  140.750                    11
#
#       Discounted Price
# 3045           13.9000
# 1602            6.6720
# 388             2.6240
# 141             8.8200
# 9619          139.9600
# 1273           10.3680
# 7263           31.6800
# 1377           16.4000
# 8394          766.6575
# 9971          140.7500
